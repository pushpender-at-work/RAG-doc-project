# %%
import tiktoken

encoding=tiktoken.encoding_for_model("gpt-4o")

# %%
tokens = encoding.encode(" hellow and is ai going to die.")

# %%
tokens
# Out:
# [15760, 384, 326, 382, 8440, 2966, 316, 1076, 13]
